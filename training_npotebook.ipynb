# %%
# %%bash
# mace_run_train \
# --name=mace_seed_1_trial0 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/dataset_trial0.extxyz" \
# --valid_file="/home/mehuldarak/athena/val_trial0.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1.0 \
# --energy_weight=1.0 \
# --forces_weight=20.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=0.0005 \
# --batch_size=2 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# Traceback (most recent call last):
#   File "/home/mehuldarak/anaconda3/envs/mace310/bin/mace_run_train", line 3, in <module>
#     from mace.cli.run_train import main
#   File "/home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/mace/cli/run_train.py", line 16, in <module>
#     import torch.distributed
#   File "/home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/torch/__init__.py", line 2790, in <module>
#     from torch import _meta_registrations
#   File "/home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/torch/_meta_registrations.py", line 1104, in <module>
#     [aten.linalg_householder_product.default, aten.linalg_householder_product.out]
#   File "/home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/torch/_ops.py", line 1179, in __getattr__
#     OpOverload(self, op_, op_dk_, schema, tags)
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_seed_2_trial0 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/dataset_trial0.extxyz" \
# --valid_file="/home/mehuldarak/athena/val_trial0.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=4 \
# --lora_alpha=1.0 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=0.005 \
# --batch_size=2 \
# --max_num_epochs=400 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=2
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-13 15:23:31.053 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-13 15:23:31.053 INFO: MACE version: 0.3.15
# 2026-03-13 15:23:31.073 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_seed_2_trial0 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/dataset_trial0.extxyz" \
# --valid_file="/home/mehuldarak/athena/val_trial0.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1.0 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=0.0008 \
# --batch_size=2 \
# --max_num_epochs=400 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=2
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-13 15:32:39.678 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-13 15:32:39.679 INFO: MACE version: 0.3.15
# 2026-03-13 15:32:39.700 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_seed_1_trial0_rank8 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/DFTFE_labelled_data/dataset_trial0.extxyz" \
# --valid_file="/home/mehuldarak/athena/DFTFE_labelled_data/val_trial0.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=8 \
# --lora_alpha=1.0 \
# --energy_weight=1.0 \
# --forces_weight=20.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=0.0005 \
# --batch_size=2 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-19 18:31:21.216 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-19 18:31:21.216 INFO: MACE version: 0.3.15
# 2026-03-19 18:31:21.234 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_split1_trial0 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/DFTFE_labelled_data/split1_trial0/train_split1_trail0_containsRuns_2AsWell.extxyz" \
# --valid_file="/home/mehuldarak/athena/DFTFE_labelled_data/split1_trial0/val_split1_trail0_containsRuns_2AsWell.extxyz" \
# --test_file="/home/mehuldarak/athena/DFTFE_labelled_data/split1_trial0/test_split1_trial0_containsRuns_2AsWell.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1.0 \
# --energy_weight=1.0 \
# --forces_weight=3.5 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=0.0005 \
# --scheduler=ReduceLROnPlateau \
# --lr_factor=0.5 \
# --scheduler_patience=10   \
# --batch_size=2 \
# --max_num_epochs=300 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-19 21:33:38.028 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-19 21:33:38.028 INFO: MACE version: 0.3.15
# 2026-03-19 21:33:38.046 INFO: CUDA version: 12.8, CUDA device: 0
# ...
