# %%
from ase.io import read
# Load the trajectory
traj = read('/home/mehuldarak/athena_embeddings_309machine/309_batch10.extxyz', index=':')
# Print the number of frames
print(len(traj))
# Out:
# ---------------------------------------------------------------------------
# UnknownFileTypeError                      Traceback (most recent call last)
# Cell In[37], line 3
#       1 from ase.io import read
#       2 # Load the trajectory
# ----> 3 traj = read('/home/mehuldarak/athena_embeddings_309machine/309_batch12.extxyz', index=':')
#       4 # Print the number of frames
#       5 print(len(traj))
#
# File ~/anaconda3/envs/mace/lib/python3.13/site-packages/ase/io/formats.py:808, in read(filename, index, format, parallel, do_not_split_by_at_sign, **kwargs)
#     806 if index is None:
#     807     index = -1
# --> 808 format = format or filetype(filename, read=isinstance(filename, str))
#     810 io = get_ioformat(format)
#     811 if isinstance(index, (slice, str)):
#
# File ~/anaconda3/envs/mace/lib/python3.13/site-packages/ase/io/formats.py:998, in filetype(filename, read, guess)
#     995     fd.seek(0)
#     997 if len(data) == 0:
# ...
