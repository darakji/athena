# %%
# %%bash
# mace_run_train \
# --name=mace_fps_split1 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_1/fps_dftfe_split_1_train.extxyz" \
# --valid_file=/home/mehuldarak/athena/fps_dftfe_data/split_1/fps_dftfe_split_1_val.extxyz \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1.0 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=0.000001 \
# --batch_size=2 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-24 23:46:04.181 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-24 23:46:04.181 INFO: MACE version: 0.3.15
# 2026-03-24 23:46:04.200 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_fps_split3 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_3/fps_dftfe_split_3_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_3/fps_dftfe_split_3_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=0.000005 \
# --batch_size=2 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=3
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-24 16:59:38.051 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-24 16:59:38.051 INFO: MACE version: 0.3.15
# 2026-03-24 16:59:38.069 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_fps_split2 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_2/fps_dftfe_split_2_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_2/fps_dftfe_split_2_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-8 \
# --batch_size=2 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-24 18:24:46.339 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-24 18:24:46.339 INFO: MACE version: 0.3.15
# 2026-03-24 18:24:46.370 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_fps_split4 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_4/fps_dftfe_split_4_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_4/fps_dftfe_split_4_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=7e-3 \
# --batch_size=2 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-24 23:34:27.167 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-24 23:34:27.167 INFO: MACE version: 0.3.15
# 2026-03-24 23:34:27.185 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_fps_split5 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_5/fps_dftfe_split_5_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_5/fps_dftfe_split_5_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-5 \
# --batch_size=2 \
# --max_num_epochs=28 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-25 00:03:42.271 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-25 00:03:42.271 INFO: MACE version: 0.3.15
# 2026-03-25 00:03:42.289 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name=mace_fps_split5 \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_5/fps_dftfe_split_5_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_5/fps_dftfe_split_5_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-8 \
# --batch_size=2 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-25 00:06:53.427 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-25 00:06:53.427 INFO: MACE version: 0.3.15
# 2026-03-25 00:06:53.446 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# x=6
# mace_run_train \
# --name="mace_fps_split${x}" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_6/fps_dftfe_split_${x}_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_6/fps_dftfe_split_${x}_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-2 \
# --batch_size=4 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1

# %%
# %%bash
# x=7
# mace_run_train \
# --name="mace_fps_split${x}" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=4.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-4 \
# --batch_size=4 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-25 00:32:54.639 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-25 00:32:54.639 INFO: MACE version: 0.3.15
# 2026-03-25 00:32:54.658 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# x=8
# mace_run_train \
# --name="mace_fps_split${x}" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=4.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-4 \
# --batch_size=4 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1

# %%
# %%bash
# x=12
# mace_run_train \
# --name="mace_fps_split${x}" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=5.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-4 \
# --batch_size=4 \
# --max_num_epochs=120 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-25 00:58:09.700 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-25 00:58:09.700 INFO: MACE version: 0.3.15
# 2026-03-25 00:58:09.719 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# x=17
# mace_run_train \
# --name="mace_fps_split${x}" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_${x}/fps_dftfe_split_${x}_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_${x}/fps_dftfe_split_${x}_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=2.0 \
# --forces_weight=1.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-3 \
# --batch_size=4 \
# --max_num_epochs=160 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-28 23:59:35.721 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-28 23:59:35.721 INFO: MACE version: 0.3.15
# 2026-03-28 23:59:35.739 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# x=2
# mace_run_train \
# --name="mace_fps_split${x}" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=2.0 \
# --forces_weight=1.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-3 \
# --batch_size=4 \
# --max_num_epochs=160 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-25 01:31:19.735 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-25 01:31:19.736 INFO: MACE version: 0.3.15
# 2026-03-25 01:31:19.754 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# x=7
# mace_run_train \
# --name="mace_fps_split${x}" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=2.0 \
# --forces_weight=1.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-3 \
# --batch_size=4 \
# --max_num_epochs=160 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-25 01:36:34.016 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-25 01:36:34.016 INFO: MACE version: 0.3.15
# 2026-03-25 01:36:34.035 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# x=12
# mace_run_train \
# --name="mace_fps_split${x}" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_data/split_${x}/fps_dftfe_split_${x}_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=3.0 \
# --forces_weight=1.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-4 \
# --batch_size=4 \
# --max_num_epochs=160 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-25 01:57:49.846 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-25 01:57:49.846 INFO: MACE version: 0.3.15
# 2026-03-25 01:57:49.866 INFO: CUDA version: 12.8, CUDA device: 0
# ...
