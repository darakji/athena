# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_SaveIT0" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17/fps_dftfe_split_17_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=3.0 \
# --forces_weight=1.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-5 \
# --batch_size=2 \
# --max_num_epochs=260 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-29 03:19:30.078 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-29 03:19:30.078 INFO: MACE version: 0.3.15
# 2026-03-29 03:19:30.097 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_SaveIT0" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=20.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-5 \
# --batch_size=2 \
# --max_num_epochs=260 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-29 16:13:37.611 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-29 16:13:37.611 INFO: MACE version: 0.3.15
# 2026-03-29 16:13:37.637 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_FTUnivFromStart" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=10.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-6 \
# --batch_size=2 \
# --max_num_epochs=260 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-29 16:33:16.766 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-29 16:33:16.767 INFO: MACE version: 0.3.15
# 2026-03-29 16:33:16.798 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_FTUnivFromStart_wBurov" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_train_burov.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=2.0 \
# --forces_weight=20.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-5 \
# --batch_size=2 \
# --max_num_epochs=260 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=17
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-29 16:45:18.668 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-29 16:45:18.668 INFO: MACE version: 0.3.15
# 2026-03-29 16:45:18.689 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_FTUnivFromStart_wBurov_256" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_train_burov.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --hidden_irreps='256x0e + 256x1o + 256x2o' \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=2.0 \
# --forces_weight=20.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-3 \
# --batch_size=2 \
# --max_num_epochs=260 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-29 16:50:30.173 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-29 16:50:30.173 INFO: MACE version: 0.3.15
# 2026-03-29 16:50:30.191 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_SaveIT0_256" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_save256/fps_dftfe_split_17_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_save256/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --hidden_irreps='256x0e + 256x1o + 256x2o' \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=1.0 \
# --forces_weight=5.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-6 \
# --batch_size=2 \
# --max_num_epochs=320 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-30 01:23:57.559 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-30 01:23:57.559 INFO: MACE version: 0.3.15
# 2026-03-30 01:23:57.577 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_SaveIT0_256_contiued" \
# --foundation_model="/home/mehuldarak/athena/mace_fps_training/checkpoints/mace_fps_split17_SaveIT0_256_run-1.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_train_wburov.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17_plusSuperSeed_Centered/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --hidden_irreps='256x0e + 256x1o + 256x2o' \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=3.0 \
# --forces_weight=1.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=5e-5 \
# --batch_size=2 \
# --max_num_epochs=150 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
# Out:
# bash: /home/mehuldarak/anaconda3/lib/libtinfo.so.6: no version information available (required by bash)
# /home/mehuldarak/anaconda3/envs/mace310/lib/python3.10/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.
# 2026-03-30 00:06:37.910 INFO: ===========VERIFYING SETTINGS===========
# 2026-03-30 00:06:37.910 INFO: MACE version: 0.3.15
# 2026-03-30 00:06:37.928 INFO: CUDA version: 12.8, CUDA device: 0
# ...

# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_SaveIT0_256" \
# --foundation_model="/home/mehuldarak/MACE_models/universal_09072025/mace-omat-0-medium.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17/fps_dftfe_split_17_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --hidden_irreps='256x0e + 256x1o + 256x2o' \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=3.0 \
# --forces_weight=1.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-4 \
# --batch_size=2 \
# --max_num_epochs=260 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1

# %%
# %%bash
# mace_run_train \
# --name="mace_fps_split17_SaveIT0_256" \
# --foundation_model="/home/mehuldarak/athena/mace_fps_training/mace_fps_split17_it0_final_epoch156.model" \
# --train_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17/fps_dftfe_split_17_train.extxyz" \
# --valid_file="/home/mehuldarak/athena/fps_dftfe_and_emb_data/split_17/fps_dftfe_split_17_val.extxyz" \
# --restart_latest \
# --hidden_irreps='256x0e + 256x1o + 256x2o' \
# --lora=True \
# --lora_rank=5 \
# --lora_alpha=1 \
# --energy_weight=3.0 \
# --forces_weight=1.0 \
# --stress_weight=0.0 \
# --E0s="{3:-190.7590256408,8:-442.9888796243,40:-1380.1817128081,57:-958.0774205521}" \
# --lr=1e-4 \
# --batch_size=2 \
# --max_num_epochs=260 \
# --default_dtype=float32 \
# --device=cuda \
# --seed=1
